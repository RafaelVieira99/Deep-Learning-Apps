# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %ls
# %cd gdrive/MyDrive/YOLO/yolo_original/v1/YOLO/
# Out:
# Mounted at /content/gdrive
# gdrive/  sample_data/
# /content/gdrive/MyDrive/YOLO/yolo_original/v1/YOLO

# %%
# Out:
# '/content'

# %%
# código para escrever os nomes das imagens nos ficheiros

#import os
#lista = os.listdir("KITTI_dataset/Imgs") # returns list

#f1 = open("data/KITTI/training.txt", 'w')
#f2 = open("data/KITTI/testing.txt", 'w')

#for i in range(len(lista)):
 # if (i < 400):
   # f1.write("KITTI_dataset/Imgs/"+lista[i])
  #  f1.write('\n')

 # if (i>=400 and i<500):
 #   f2.write("KITTI_dataset/Imgs/"+lista[i])
 #   f2.write('\n')


#f1.close()
#f2.close()

# %%
# !python train.py
# Out:
# Streaming output truncated to the last 5000 lines.
# +------------+--------------+--------------+--------------+
# | grid_size  | 13           | 26           | 52           |
# | loss       | 0.057620     | 0.239578     | 0.363696     |
# | x          | 0.013477     | 0.033455     | 0.044854     |
# | y          | 0.006507     | 0.009555     | 0.026520     |
# | w          | 0.011927     | 0.033190     | 0.025189     |
# | h          | 0.006375     | 0.027244     | 0.017400     |
# | conf       | 0.019273     | 0.136112     | 0.249641     |
# | cls        | 0.000061     | 0.000021     | 0.000091     |
# | cls_acc    | 100.00%      | 100.00%      | 100.00%      |
# | recall50   | 1.000000     | 0.961538     | 0.896552     |
# | recall75   | 0.913043     | 0.769231     | 0.793103     |
# | precision  | 1.000000     | 0.925926     | 0.577778     |
# | conf_obj   | 0.993102     | 0.939969     | 0.908213     |
# | conf_noobj | 0.000116     | 0.000323     | 0.000467     |
# ...

# %%
# !python detect.py --weights_path "checkpoints/KITTI_classID0_yolov3_25.pth"

# %%
# !python test.py --weights_path "checkpoints/KITTI_classID0_yolov3_25.pth"
# Out:
# Namespace(batch_size=8, model_def='config/tinyv3.cfg', data_config='config/KITTI_class_ID_0.data', weights_path='checkpoints/KITTI_classID0_yolov3_25.pth', class_path='data/KITTI/classes.names', iou_thres=0.5, conf_thres=0.5, nms_thres=0.5, n_cpu=8, img_size=416)
# Compute mAP...
# Detecting objects: 100% 13/13 [00:42<00:00,  3.24s/it]
# Computing AP: 100% 1/1 [00:00<00:00, 524.68it/s]
# Average Precisions:
# + Class '0' (Car) - AP: 0.3055312880768555
# + Class '0' (Car) - precision: 0.31203007518796994
# + Class '0' (Car) - recall: 0.5763888888888888
# + Class '0' (Car) - f1: 0.4048780487804878
# mAP: 0.3055312880768555

# %%
# !python test.py --weights_path "checkpoints/pesos_scratch.pth"
# Out:
# Namespace(batch_size=8, model_def='config/yolov3_1class.cfg', data_config='config/KITTI_class_ID_0.data', weights_path='checkpoints/pesos_scratch.pth', class_path='data/KITTI/classes.names', iou_thres=0.5, conf_thres=0.5, nms_thres=0.5, n_cpu=8, img_size=416)
# Compute mAP...
# Detecting objects: 100% 13/13 [01:24<00:00,  6.50s/it]
# Computing AP: 100% 1/1 [00:00<00:00, 479.08it/s]
# Average Precisions:
# + Class '0' (Car) - AP: 0.5471669310766183
# + Class '0' (Car) - precision: 0.4462809917355372
# + Class '0' (Car) - recall: 0.75
# + Class '0' (Car) - f1: 0.5595854922279793
# mAP: 0.5471669310766183

# %%
# !python train.py --pretrained_weights "checkpoints/KITTI_classID0_yolov3_175.pth"
# Out:
# Streaming output truncated to the last 5000 lines.
# +------------+--------------+--------------+--------------+
# | grid_size  | 15           | 30           | 60           |
# | loss       | 0.240455     | 0.216930     | 0.165445     |
# | x          | 0.018652     | 0.007578     | 0.040133     |
# | y          | 0.008720     | 0.006264     | 0.014414     |
# | w          | 0.022652     | 0.013319     | 0.003937     |
# | h          | 0.015786     | 0.027732     | 0.007523     |
# | conf       | 0.174642     | 0.162036     | 0.099436     |
# | cls        | 0.000003     | 0.000001     | 0.000001     |
# | cls_acc    | 100.00%      | 100.00%      | 100.00%      |
# | recall50   | 1.000000     | 0.954545     | 1.000000     |
# | recall75   | 0.894737     | 0.863636     | 0.909091     |
# | precision  | 0.904762     | 0.777778     | 0.500000     |
# | conf_obj   | 0.989802     | 0.962840     | 0.986459     |
# | conf_noobj | 0.000594     | 0.000414     | 0.000401     |
# ...
