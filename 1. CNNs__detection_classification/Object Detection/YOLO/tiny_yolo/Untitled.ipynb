# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %ls
# %cd gdrive/MyDrive/YOLO/tiny_yolo/
# Out:
# Mounted at /content/gdrive
# gdrive/  sample_data/
# /content/gdrive/MyDrive/YOLO/tiny_yolo

# %%
# !python test.py --weights_path "check/KITTI_classID0_yolov3_200.pth"
# Out:
# Namespace(batch_size=1, model_def='config/tinyv3.cfg', data_config='config/KITTI_class_ID_0.data', weights_path='check/KITTI_classID0_yolov3_200.pth', class_path='data/KITTI/classes.names', iou_thres=0.5, conf_thres=0.5, nms_thres=0.5, n_cpu=8, img_size=416)
# Compute mAP...
# Detecting objects: 100% 1/1 [00:08<00:00,  8.90s/it]
# Computing AP: 100% 1/1 [00:00<00:00, 2439.97it/s]
# Average Precisions:
# + Class '0' (Car) - AP: 0.586489898989899
# + Class '0' (Car) - precision: 0.5
# + Class '0' (Car) - recall: 0.6666666666666666
# + Class '0' (Car) - f1: 0.5714285714285715
# mAP: 0.586489898989899

# %%
# !python detect.py --weights_path "check/KITTI_classID0_yolov3_200.pth"
# Out:
# Namespace(image_folder='KITTI_dataset/Imgs/', model_def='config/tinyv3.cfg', weights_path='check/KITTI_classID0_yolov3_200.pth', class_path='data/KITTI/classes.names', conf_thres=0.5, nms_thres=0.5, batch_size=1, n_cpu=4, img_size=416)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#
# Performing object detection:
# imgs path:KITTI_dataset/Imgs/000498.png
#
# imgs path:KITTI_dataset/Imgs/000497.png
#
# imgs path:KITTI_dataset/Imgs/000499.png
#
# imgs path:KITTI_dataset/Imgs/000495.png
#
# imgs path:KITTI_dataset/Imgs/000496.png

# %%
# !zip -r .zip original_folder
